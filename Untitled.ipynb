# %%
import sys
# !{sys.executable} -m pip install elasticsearch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: elasticsearch in /home/void/.local/lib/python3.14/site-packages (9.3.0)
# Requirement already satisfied: anyio in /usr/lib/python3.14/site-packages (from elasticsearch) (4.12.1)
# Requirement already satisfied: elastic-transport<10,>=9.2.0 in /home/void/.local/lib/python3.14/site-packages (from elasticsearch) (9.2.1)
# Requirement already satisfied: python-dateutil in /usr/lib/python3.14/site-packages (from elasticsearch) (2.9.0.post0)
# Requirement already satisfied: sniffio in /usr/lib/python3.14/site-packages (from elasticsearch) (1.3.1)
# Requirement already satisfied: typing-extensions in /usr/lib/python3.14/site-packages (from elasticsearch) (4.15.0)
# Requirement already satisfied: urllib3<3,>=1.26.2 in /usr/lib/python3.14/site-packages (from elastic-transport<10,>=9.2.0->elasticsearch) (2.6.3)
# Requirement already satisfied: certifi in /usr/lib/python3.14/site-packages (from elastic-transport<10,>=9.2.0->elasticsearch) (2025.7.9)
# Requirement already satisfied: idna>=2.8 in /usr/lib/python3.14/site-packages (from anyio->elasticsearch) (3.10)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.14/site-packages (from python-dateutil->elasticsearch) (1.17.0)

# %%
import pandas as pd
import numpy as np
import sys
from elasticsearch import Elasticsearch

print("--- Verificación de Entorno ---")
print(f"Versión de Python: {sys.version}")
print(f"¿Entorno virtual activo?: {'✅ Sí' if sys.prefix != sys.base_prefix else '❌ No'}")

# Prueba de procesamiento
df = pd.DataFrame({
    'Módulo': ['Ingesta', 'Procesamiento', 'IA'],
    'Estado': ['Listo', 'Listo', 'Listo'],
    'Score': np.random.rand(3)
})

print("\nValidación de Librerías:")
print(df)

try:
    es = Elasticsearch("http://localhost:9200")
    print("\n✅ Cliente de Elasticsearch listo.")
except:
    print("\n⚠️ Cliente de Elastic cargado (requiere servidor activo para conectar).")
# Out:
# --- Verificación de Entorno ---
# Versión de Python: 3.14.2 (main, Dec  5 2025, 00:00:00) [GCC 15.2.1 20251111 (Red Hat 15.2.1-4)]
# ¿Entorno virtual activo?: ❌ No
#
# Validación de Librerías:
#           Módulo Estado     Score
# 0        Ingesta  Listo  0.937634
# 1  Procesamiento  Listo  0.818521
# 2             IA  Listo  0.289543
#
# ✅ Cliente de Elasticsearch listo.
